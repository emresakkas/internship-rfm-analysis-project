# %% [markdown]
# # First we add the libraries we will use

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="white")
import scipy.stats as stats
from scipy.stats import spearmanr
import os
import glob
import datetime as dt
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
import plotly.io as pio
import statsmodels.api as sm

# %% [markdown]
# # We define and filter data

# %%
df = pd.read_csv("/Users/emreserhatakkas/Downloads/project_data.csv")

# %%
df3 = pd.concat(map(pd.read_csv, glob.glob('/Users/emreserhatakkas/Downloads/emresakkas_churndata/*.csv')))
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py:294: DtypeWarning: Columns (36,58,59,64,65,66,67,69,70,73,75,76,77,80,81,84,86,87,89,90,95,97,99,100,102,103,105,106,107,108) have mixed types.Specify dtype option on import or set low_memory=False.
#   op = _Concatenator(
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py:294: DtypeWarning: Columns (64,65,66,67,69,70,73,75,76,77,80,81,84,86,87,89,90,95,97,99,100,102,103,105,106,107,108) have mixed types.Specify dtype option on import or set low_memory=False.
#   op = _Concatenator(
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py:294: DtypeWarning: Columns (39,64,65,66,67,69,70,73,75,76,77,80,81,84,86,87,89,90,95,97,99,100,102,103,105,106,107,108) have mixed types.Specify dtype option on import or set low_memory=False.
#   op = _Concatenator(
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py:294: DtypeWarning: Columns (12,64,65,66,67,69,70,73,75,76,77,80,81,84,86,87,89,90,95,97,99,100,102,103,105,106,107,108) have mixed types.Specify dtype option on import or set low_memory=False.
#   op = _Concatenator(
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py:294: DtypeWarning: Columns (12,36,39,58,59,64,65,66,67,69,70,73,75,76,77,80,81,84,86,87,89,90,95,97,99,100,102,103,105,106,107,108) have mixed types.Specify dtype option on import or set low_memory=False.
#   op = _Concatenator(

# %%
main_data = df3.filter(items = ['industry','churn_type'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97419 entries, 0 to 97418
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            97419 non-null  int64
#  1   created_at         97419 non-null  object
#  2   account_type       97419 non-null  object
#  3   status             97419 non-null  object
#  4   first_upgrade      97419 non-null  object
#  5   last_upgrade       97419 non-null  object
#  6   cancel_date        97419 non-null  object
#  7   activeness         45320 non-null  object
#  8   total_paid_months  97419 non-null  int64
#  9   ever_paid          97419 non-null  int64
#  10  total_amount_paid  97419 non-null  int64
#  11  plan               29007 non-null  object
#  12  churn_type         29007 non-null  object
#  13  churn_date         29007 non-null  object
#  14  currency           97419 non-null  object
# dtypes: int64(4), object(11)
# memory usage: 11.1+ MB

# %%
df.head()
# Out:
#       user_id               created_at account_type  status  \
# 0  4514312841  2020-04-14 08:54:10 UTC     PLATINUM  ACTIVE
# 1  4545592751  2020-08-12 15:48:38 UTC         GOLD  ACTIVE
# 2  4560543341  2020-10-05 05:35:58 UTC         GOLD  ACTIVE
# 3  4500768231  2020-01-30 10:23:54 UTC         GOLD  ACTIVE
# 4  4534521641  2020-07-01 13:44:06 UTC         FREE  ACTIVE
#
#              first_upgrade             last_upgrade              cancel_date  \
# 0  2020-04-14 09:06:03 UTC  2021-04-25 17:29:17 UTC  2020-04-25 14:03:35 UTC
# 1  2015-09-24 19:19:48 UTC  2021-08-12 06:36:09 UTC  1970-01-01 00:00:00 UTC
# 2  2020-10-05 05:38:37 UTC  2021-10-25 06:19:16 UTC  2021-10-25 06:10:02 UTC
# 3  2020-01-30 10:25:17 UTC  2022-04-11 09:40:43 UTC  2022-04-08 22:57:42 UTC
# 4  2016-05-06 11:06:07 UTC  2019-09-06 12:07:11 UTC  1970-01-01 00:00:00 UTC
#
#     activeness  total_paid_months  ever_paid  total_amount_paid    plan  \
# 0          NaN                 24          1              10079     NaN
# 1  very active                 20          1               3726  SILVER
# 2          NaN                 18          1               3113     NaN
# 3  very active                 27          1               3050     NaN
# 4          NaN                 41          1               3023     NaN
#
#   churn_type               churn_date currency
# 0        NaN                      NaN      USD
# 1  LONG-TERM  2020-04-26 16:32:56 UTC      USD
# 2        NaN                      NaN      USD
# 3        NaN                      NaN      USD
# 4        NaN                      NaN      USD

# %% [markdown]
# # We convert date indicating variables from object to datetime

# %%
df[["created_at","first_upgrade","last_upgrade","cancel_date","churn_date"]] = df[["created_at","first_upgrade","last_upgrade","cancel_date","churn_date"]].apply(pd.to_datetime)

# %% [markdown]
# # We define paid-customers terms (short, mid, long)

# %%
a = df.loc[(df.total_paid_months > 0) & (df.total_paid_months <= 3)]
b = df.loc[(df.total_paid_months > 3) & (df.total_paid_months < 14)]
c = df.loc[(df.total_paid_months >= 14)]
d = df.loc[(df.total_paid_months < 1)]

# %%
a = a.assign(customer_term_type = 'short_term')
b = b.assign(customer_term_type = 'mid_term')
c = c.assign(customer_term_type = 'long_term')
d = d.assign(customer_term_type = 'free')

# %%
df = pd.concat([a,b,c,d])

# %% [markdown]
# # We get information about the latest version of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97419 entries, 740 to 97418
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             97419 non-null  int64
#  1   created_at          97419 non-null  datetime64[ns, UTC]
#  2   account_type        97419 non-null  object
#  3   status              97419 non-null  object
#  4   first_upgrade       97419 non-null  datetime64[ns, UTC]
#  5   last_upgrade        97419 non-null  datetime64[ns, UTC]
#  6   cancel_date         97419 non-null  datetime64[ns, UTC]
#  7   activeness          45320 non-null  object
#  8   total_paid_months   97419 non-null  int64
#  9   ever_paid           97419 non-null  int64
#  10  total_amount_paid   97419 non-null  int64
#  11  plan                29007 non-null  object
#  12  churn_type          29007 non-null  object
#  13  churn_date          29007 non-null  datetime64[ns, UTC]
#  14  currency            97419 non-null  object
#  15  customer_term_type  97419 non-null  object
# dtypes: datetime64[ns, UTC](5), int64(4), object(7)
# memory usage: 12.6+ MB

# %% [markdown]
# # We will calculate monthly and termly churn ratios, for this reason we must filter dates. Now we will filter data by month.

# %%
now = pd.Timestamp.now().to_period('m')
YearMonths = pd.period_range(now-30, freq='M', periods=31).strftime('%Y-%m').tolist()

# %% [markdown]
# # We define churn and plan rates functions. After defining we'll calculate churn and plan ratios

# %%
dict_stmcr = {}
for i, ym in enumerate(YearMonths[1:]):
    t2 = df.loc[(df.churn_date < ym)]
    u2 = t2[t2['churn_type'] == "SHORT-TERM"].value_counts().sum()
    c2 = t2[t2['customer_term_type'] != "free"].value_counts().sum()
    stmcr = u2/c2
    dict_stmcr[YearMonths[i]]= stmcr

# %%
dict_ltmcr = {}
for i, ym in enumerate(YearMonths[1:]):
    t3 = df.loc[(df.churn_date < ym)]
    u3 = t3[t3['churn_type'] == "LONG-TERM"].value_counts().sum()
    c3 = t3[t3['customer_term_type'] != "free"].value_counts().sum()
    ltmcr = u3/c3
    dict_ltmcr[YearMonths[i]]= ltmcr

# %%
dict_mtmcr = {}
for i, ym in enumerate(YearMonths[1:]):
    t4 = df.loc[(df.churn_date < ym)]
    u4 = t4[t4['churn_type'] == "MID-TERM"].value_counts().sum()
    c4 = t4[t4['customer_term_type'] != "free"].value_counts().sum()
    mtmcr = u4/c4
    dict_mtmcr[YearMonths[i]]= mtmcr

# %%
stmcr_date = list(dict_stmcr.keys())
stmcr_values = list(dict_stmcr.values())
ltmcr_date = list(dict_ltmcr.keys())
ltmcr_values = list(dict_ltmcr.values())
mtmcr_date = list(dict_mtmcr.keys())
mtmcr_values = list(dict_mtmcr.values())
totalchurn_date = list(dict_totalchurn.keys())
totalchurn_values = list(dict_totalchurn.values())

# %%
all_churnpercentages = pd.DataFrame(list(zip(stmcr_date, stmcr_values,mtmcr_values,ltmcr_values)),
                           columns =['Date', 'Short-Term Churn Ratio(%)','Mid-Term Churn Ratio(%)','Long-Term Churn Ratio(%)'])

# %%
all_churnpercentages
# Out:
#        Date  Short-Term Churn Ratio(%)  Mid-Term Churn Ratio(%)  \
# 0   2020-01                   1.000000                 0.000000
# 1   2020-02                   0.958333                 0.041667
# 2   2020-03                   1.016949                 0.016949
# 3   2020-04                   0.962963                 0.046296
# 4   2020-05                   0.939759                 0.072289
# 5   2020-06                   0.929961                 0.085603
# 6   2020-07                   0.890208                 0.112760
# 7   2020-08                   0.851770                 0.152655
# 8   2020-09                   0.827465                 0.177817
# 9   2020-10                   0.809869                 0.193033
# 10  2020-11                   0.791425                 0.213210
# 11  2020-12                   0.778320                 0.224609
# 12  2021-01                   0.750619                 0.254335
# 13  2021-02                   0.744666                 0.258775
# 14  2021-03                   0.753107                 0.248023
# 15  2021-04                   0.754419                 0.252747
# 16  2021-05                   0.741591                 0.262920
# 17  2021-06                   0.730309                 0.271143
# 18  2021-07                   0.717814                 0.284491
# 19  2021-08                   0.702385                 0.295503
# 20  2021-09                   0.692030                 0.302694
# 21  2021-10                   0.682410                 0.307123
# 22  2021-11                   0.671615                 0.308290
# 23  2021-12                   0.664175                 0.309355
# 24  2022-01                   0.653635                 0.314395
# 25  2022-02                   0.652028                 0.311767
# 26  2022-03                   0.651479                 0.307141
# 27  2022-04                   0.654765                 0.304411
# 28  2022-05                   0.655931                 0.313287
# 29  2022-06                   0.644393                 0.330452
#
#     Long-Term Churn Ratio(%)
# 0                   0.000000
# 1                   0.000000
# 2                   0.000000
# 3                   0.009259
# 4                   0.006024
# 5                   0.003891
# 6                   0.011869
# 7                   0.008850
# 8                   0.007042
# 9                   0.007257
# 10                  0.008111
# 11                  0.010742
# 12                  0.010735
# 13                  0.011012
# 14                  0.012429
# 15                  0.011945
# 16                  0.013946
# 17                  0.016334
# 18                  0.016793
# 19                  0.020525
# 20                  0.023327
# 21                  0.028083
# 22                  0.037451
# 23                  0.042837
# 24                  0.049141
# 25                  0.052967
# 26                  0.057962
# 27                  0.061565
# 28                  0.068814
# 29                  0.076906

# %%
dict_stcr = {}
for i, ym in enumerate(YearMonths[1:]):
    j1 = df.loc[(df.churn_date < ym)]
    j2 = j1[j1['churn_type'] == "SHORT-TERM"].value_counts().sum()
    j3 = j1[j1['customer_term_type'] == "short_term"].value_counts().sum()
    stcr = j3/j2
    dict_stcr[YearMonths[i]]= stcr

# %%
dict_mtcr = {}
for i, ym in enumerate(YearMonths[1:]):
    j4 = df.loc[(df.churn_date < ym)]
    j5 = j4[j4['churn_type'] == "MID-TERM"].value_counts().sum()
    j6 = j4[j4['customer_term_type'] == "mid_term"].value_counts().sum()
    mtcr = j5/j6
    dict_mtcr[YearMonths[i]]= mtcr

# %%
dict_ltcr = {}
for i, ym in enumerate(YearMonths[1:]):
    j7 = df.loc[(df.churn_date < ym)]
    j8 = j7[j7['churn_type'] == "LONG-TERM"].value_counts().sum()
    j9 = j7[j7['customer_term_type'] == "long_term"].value_counts().sum()
    ltcr = j8/j9
    dict_ltcr[YearMonths[i]]= ltcr
# Out:
# /var/folders/g6/8s7c14n52sg8ylcp_fwp_4mh0000gn/T/ipykernel_13191/1135261545.py:6: RuntimeWarning: invalid value encountered in long_scalars
#   ltcr = j8/j9

# %%
dict_totalchurn = {}
for i, ym in enumerate(YearMonths[1:]):
    t5 = df.loc[(df.churn_date < ym)]
    u5 = t5['churn_type'].value_counts().sum()
    c5 = t5[t5['customer_term_type'] != 'free'].value_counts().sum()
    total_churn = c5/u5
    dict_totalchurn[YearMonths[i]]= total_churn

# %%
stcr_date = list(dict_stcr.keys())
stcr_values = list(dict_stcr.values())
ltcr_values = list(dict_ltcr.values())
mtcr_values = list(dict_mtcr.values())
totalchurn_values = list(dict_totalchurn.values())

# %%
all_churnrates = pd.DataFrame(list(zip(stcr_date, stcr_values,mtcr_values,ltcr_values,totalchurn_values)),
                           columns =['Date', 'Short-Term Churn Ratio','Mid-Term Churn Ratio','Long-Term Churn Ratio','Total Churn Ratio'])

# %%
all_churnrates
# Out:
#        Date  Short-Term Churn Ratio  Mid-Term Churn Ratio  \
# 0   2020-01                0.571429              0.000000
# 1   2020-02                0.521739              0.111111
# 2   2020-03                0.350000              0.047619
# 3   2020-04                0.307692              0.131579
# 4   2020-05                0.339744              0.210526
# 5   2020-06                0.359833              0.258824
# 6   2020-07                0.343333              0.322034
# 7   2020-08                0.345455              0.436709
# 8   2020-09                0.361702              0.500000
# 9   2020-10                0.374552              0.534137
# 10  2020-11                0.399707              0.589744
# 11  2020-12                0.409034              0.610080
# 12  2021-01                0.419142              0.665227
# 13  2021-02                0.475970              0.698885
# 14  2021-03                0.531883              0.688088
# 15  2021-04                0.555415              0.695138
# 16  2021-05                0.565265              0.689989
# 17  2021-06                0.578529              0.697479
# 18  2021-07                0.582569              0.705882
# 19  2021-08                0.586162              0.712000
# 20  2021-09                0.593900              0.714754
# 21  2021-10                0.606809              0.721223
# 22  2021-11                0.620537              0.721539
# 23  2021-12                0.647399              0.733589
# 24  2022-01                0.672163              0.755487
# 25  2022-02                0.696658              0.767327
# 26  2022-03                0.727815              0.783537
# 27  2022-04                0.758821              0.808014
# 28  2022-05                0.774597              0.850597
# 29  2022-06                0.792089              0.902269
#
#     Long-Term Churn Ratio  Total Churn Ratio
# 0                     NaN           0.205882
# 1                0.000000           0.165517
# 2                0.000000           0.154856
# 3                0.026316           0.158358
# 4                0.017857           0.148214
# 5                0.011628           0.149767
# 6                0.034483           0.144017
# 7                0.024845           0.149077
# 8                0.020408           0.150703
# 9                0.021645           0.150634
# 10               0.025180           0.157914
# 11               0.034268           0.160200
# 12               0.035422           0.167335
# 13               0.040000           0.180452
# 14               0.052009           0.195429
# 15               0.054945           0.205781
# 16               0.069815           0.213766
# 17               0.086538           0.217821
# 18               0.093923           0.220232
# 19               0.118467           0.220133
# 20               0.140940           0.222161
# 21               0.175439           0.224123
# 22               0.240117           0.232369
# 23               0.288828           0.244758
# 24               0.340076           0.254723
# 25               0.379808           0.263504
# 26               0.433036           0.279068
# 27               0.487020           0.299414
# 28               0.556731           0.313149
# 29               0.623540           0.320329

# %% [markdown]
# At 2020-01 Long-Term Churn Ratio is 0 (Zero) but in DataFrame this variable is NaN (Not a Number). Since this variable is NaN, it may cause problems for our future analysis, so we update this variable with the actual value 0 (Zero).

# %%
long_term_churn_updated = all_churnrates['Long-Term Churn Ratio'].fillna(value = 0).tolist()

# %%
all_churnrates.drop(columns = ['Long-Term Churn Ratio'], inplace=True)

# %%
all_churnrates['Long-Term Churn Ratio'] = long_term_churn_updated

# %%
all_churnrates
# Out:
#        Date  Short-Term Churn Ratio  Mid-Term Churn Ratio  \
# 0   2020-01                0.571429              0.000000
# 1   2020-02                0.521739              0.111111
# 2   2020-03                0.350000              0.047619
# 3   2020-04                0.307692              0.131579
# 4   2020-05                0.339744              0.210526
# 5   2020-06                0.359833              0.258824
# 6   2020-07                0.343333              0.322034
# 7   2020-08                0.345455              0.436709
# 8   2020-09                0.361702              0.500000
# 9   2020-10                0.374552              0.534137
# 10  2020-11                0.399707              0.589744
# 11  2020-12                0.409034              0.610080
# 12  2021-01                0.419142              0.665227
# 13  2021-02                0.475970              0.698885
# 14  2021-03                0.531883              0.688088
# 15  2021-04                0.555415              0.695138
# 16  2021-05                0.565265              0.689989
# 17  2021-06                0.578529              0.697479
# 18  2021-07                0.582569              0.705882
# 19  2021-08                0.586162              0.712000
# 20  2021-09                0.593900              0.714754
# 21  2021-10                0.606809              0.721223
# 22  2021-11                0.620537              0.721539
# 23  2021-12                0.647399              0.733589
# 24  2022-01                0.672163              0.755487
# 25  2022-02                0.696658              0.767327
# 26  2022-03                0.727815              0.783537
# 27  2022-04                0.758821              0.808014
# 28  2022-05                0.774597              0.850597
# 29  2022-06                0.792089              0.902269
#
#     Long-Term Churn Ratio  Total Churn Ratio
# 0                0.000000           0.205882
# 1                0.000000           0.165517
# 2                0.000000           0.154856
# 3                0.026316           0.158358
# 4                0.017857           0.148214
# 5                0.011628           0.149767
# 6                0.034483           0.144017
# 7                0.024845           0.149077
# 8                0.020408           0.150703
# 9                0.021645           0.150634
# 10               0.025180           0.157914
# 11               0.034268           0.160200
# 12               0.035422           0.167335
# 13               0.040000           0.180452
# 14               0.052009           0.195429
# 15               0.054945           0.205781
# 16               0.069815           0.213766
# 17               0.086538           0.217821
# 18               0.093923           0.220232
# 19               0.118467           0.220133
# 20               0.140940           0.222161
# 21               0.175439           0.224123
# 22               0.240117           0.232369
# 23               0.288828           0.244758
# 24               0.340076           0.254723
# 25               0.379808           0.263504
# 26               0.433036           0.279068
# 27               0.487020           0.299414
# 28               0.556731           0.313149
# 29               0.623540           0.320329

# %% [markdown]
# As you can see, the DataFrame has now been updated to provide a more robust analysis.

# %%
dict_goldplan = {}
for i, ym in enumerate(YearMonths[1:]):
    z4 = df.loc[(df.churn_date < ym)]
    x4 = z4[z4['plan'] == "GOLD"].value_counts().sum()
    v4 = z4[z4['customer_term_type'] != "free"].value_counts().sum()
    gold_plan = x4/v4
    dict_goldplan[YearMonths[i]]= gold_plan

# %%
dict_silverplan = {}
for i, ym in enumerate(YearMonths[1:]):
    z5 = df.loc[(df.churn_date < ym)]
    x5 = z5[z5['plan'] == "SILVER"].value_counts().sum()
    v5 = z5[z5['customer_term_type'] != "free"].value_counts().sum()
    silver_plan = x5/v5
    dict_silverplan[YearMonths[i]]= silver_plan

# %%
dict_bronzeplan = {}
for i, ym in enumerate(YearMonths[1:]):
    z6 = df.loc[(df.churn_date < ym)]
    x6 = z6[z6['plan'] == "BRONZE"].value_counts().sum()
    v6 = z6[z6['customer_term_type'] != "free"].value_counts().sum()
    bronze_plan = x6/v6
    dict_bronzeplan[YearMonths[i]]= bronze_plan

# %%
goldplan_date = list(dict_goldplan.keys())
goldplan_values = list(dict_goldplan.values())
silverplan_values = list(dict_silverplan.values())
bronzeplan_values = list(dict_bronzeplan.values())

# %%
all_plans = pd.DataFrame(list(zip(goldplan_date, goldplan_values,silverplan_values,bronzeplan_values)),
                           columns =['Date', 'Gold Plan Ratio(%)','Silver Plan Ratio(%)','Bronze Plan Ratio(%)'])

# %%
all_plans
# Out:
#        Date  Gold Plan Ratio(%)  Silver Plan Ratio(%)  Bronze Plan Ratio(%)
# 0   2020-01            0.000000              0.142857              0.857143
# 1   2020-02            0.000000              0.125000              0.833333
# 2   2020-03            0.000000              0.203390              0.813559
# 3   2020-04            0.009259              0.212963              0.787037
# 4   2020-05            0.006024              0.216867              0.789157
# 5   2020-06            0.007782              0.221790              0.785992
# 6   2020-07            0.011869              0.234421              0.762611
# 7   2020-08            0.008850              0.223451              0.776549
# 8   2020-09            0.007042              0.220070              0.778169
# 9   2020-10            0.007257              0.203193              0.793904
# 10  2020-11            0.009270              0.221321              0.777520
# 11  2020-12            0.010742              0.225586              0.773438
# 12  2021-01            0.015690              0.223782              0.772089
# 13  2021-02            0.018582              0.229181              0.763248
# 14  2021-03            0.019774              0.228249              0.762147
# 15  2021-04            0.021022              0.228380              0.766842
# 16  2021-05            0.023380              0.229286              0.762920
# 17  2021-06            0.022142              0.234846              0.757532
# 18  2021-07            0.022391              0.236088              0.756997
# 19  2021-08            0.020525              0.240567              0.753698
# 20  2021-09            0.020272              0.239933              0.753402
# 21  2021-10            0.020679              0.236405              0.755425
# 22  2021-11            0.021009              0.240237              0.750856
# 23  2021-12            0.020408              0.243079              0.747626
# 24  2022-01            0.021008              0.245707              0.745342
# 25  2022-02            0.021455              0.245391              0.744720
# 26  2022-03            0.020615              0.243800              0.747087
# 27  2022-04            0.022053              0.243371              0.749803
# 28  2022-05            0.021987              0.247207              0.762776
# 29  2022-06            0.021498              0.252549              0.771720

# %% [markdown]
# # Now we have a dataset with churn and plan ratios. We begin to visualize this datasets

# %%
fig = px.line(all_churnrates, x='Date', y=all_churnrates.columns[1:5], title="Change of Churn Rates",  color_discrete_sequence=px.colors.qualitative.G10)
fig.show("png")
print("Short-Term Customer: 3 or less than 3 months paid customer")
print("Mid-Term Customer: Between 3-14 months paid customer")
print("Long-Term Customer: 14 or more than 14 months paid customer")
# Out:
# Short-Term Customer: 3 or less than 3 months paid customer
# Mid-Term Customer: Between 3-14 months paid customer
# Long-Term Customer: 14 or more than 14 months paid customer

# %%
fig = px.bar(all_churnrates, x="Date", y="Total Churn Ratio", title="Monthly Total Churn Rate", color_discrete_sequence=px.colors.carto.Aggrnyl)
fig.show("png")

# %%
fig = px.bar(all_churnpercentages , x="Date", y=['Short-Term Churn Ratio(%)', 'Mid-Term Churn Ratio(%)', 'Long-Term Churn Ratio(%)'],title="Percentage of Churn Types \n (value=percentage)",color_discrete_sequence=px.colors.qualitative.Bold)
fig.show("png")
print("Short-Term Customer: 3 or less than 3 months paid customer")
print("Mid-Term Customer: Between 3-14 months paid customer")
print("Long-Term Customer: 14 or more than 14 months paid customer")
# Out:
# Short-Term Customer: 3 or less than 3 months paid customer
# Mid-Term Customer: Between 3-14 months paid customer
# Long-Term Customer: 14 or more than 14 months paid customer

# %%
fig = px.bar(all_plans , x="Date", y=['Gold Plan Ratio(%)', 'Silver Plan Ratio(%)', 'Bronze Plan Ratio(%)'],title="Plans of Churn Customers (Monthly) \n (value=percentage)",color_discrete_sequence=px.colors.qualitative.Antique)
fig.show("png")
print("(Storage, Guest and Professional plans are excluded)")
# Out:
# (Storage, Guest and Professional plans are excluded)

# %%
g = main_data.loc[(main_data.churn_type == "LONG-TERM")]
t = g.industry.value_counts().head(15)
u = ('construction','arts & design','non-profit organizations','education','health care and social assistance','e-commerce & retail trade','event organization','advertising, marketing & research','food & beverages','sports & activities','finance','transportation','information technology','beauty & personal care','public administration')

# %%
fig = px.pie(main_data, values = t,names = u,title = "Long-Term Churn Customers Industries",  color_discrete_sequence=px.colors.qualitative.D3)
fig.show("png")
print("(Only users with industry knowledge in the system are included in this chart.)")
# Out:
# (Only users with industry knowledge in the system are included in this chart.)

# %%
k = main_data.loc[(main_data.churn_type == "MID-TERM")]
y = k.industry.value_counts().head(15)
i = ('construction','non-profit organizations','arts & design','education','health care and social assistance','e-commerce & retail trade','sports & activities','event organization','food & beverages','finance','advertising, marketing & research','information technology','public administration','beauty & personal care','transportation')

# %%
fig = px.pie(main_data, values = y, names = i, title = "Mid-Term Churn Customers Industries",  color_discrete_sequence=px.colors.qualitative.D3)
fig.show("png")
print("(Only users with industry knowledge in the system are included in this chart.)")
# Out:
# (Only users with industry knowledge in the system are included in this chart.)

# %%
h = main_data.loc[(main_data.churn_type == "SHORT-TERM")]
p = h.industry.value_counts().head(15)
r = ('non-profit organizations','education','health care and social assistance','e-commerce & retail trade','sports & activities','event organization','arts & design','food & beverages','finance','information technology','advertising, marketing & research','public administration','real estate & leasing','beauty & personal care','transportation')

# %%
fig = px.pie(main_data, values = p,names = r,title = "Short-Term Churn Customers Industries",  color_discrete_sequence=px.colors.qualitative.D3)
fig.show("png")
print("(Only users with industry knowledge in the system are included in this chart.)")
# Out:
# (Only users with industry knowledge in the system are included in this chart.)

# %% [markdown]
# # Now that Churn analysis is finished, we can move on to Life Time Span and CLTV analysis.

# %% [markdown]
# In marketing, customer lifetime value (CLV or often CLTV), lifetime customer value (LCV), or life-time value (LTV) is a prognostication of the net profit contributed to the whole future relationship with a customer.

# %% [markdown]
# # We define CLTV function and calculate monthly CLTV

# %%
dict_cltv = {}
for i, ym in enumerate(YearMonths[1:]):
    t1 = df.loc[(df.churn_date > ym)]
    u1 = t1.user_id.value_counts().sum()
    c1 = t1.total_amount_paid.sum()
    cltv = c1/u1
    dict_cltv[YearMonths[i]]= cltv

# %%
cltv_list_date = list(dict_cltv.keys())
cltv_list_values = list(dict_cltv.values())

# %%
CLTV = pd.DataFrame(list(zip(cltv_list_date, cltv_list_values)),
                           columns =['Date', 'CLTV'])

# %%
CLTV
# Out:
#        Date        CLTV
# 0   2020-01  169.222345
# 1   2020-02  169.511607
# 2   2020-03  169.894711
# 3   2020-04  170.170980
# 4   2020-05  171.077384
# 5   2020-06  171.846360
# 6   2020-07  172.677354
# 7   2020-08  173.371242
# 8   2020-09  174.271931
# 9   2020-10  175.012974
# 10  2020-11  176.151941
# 11  2020-12  176.824630
# 12  2021-01  176.703996
# 13  2021-02  176.888094
# 14  2021-03  177.624962
# 15  2021-04  178.266299
# 16  2021-05  178.874901
# 17  2021-06  179.861116
# 18  2021-07  180.258527
# 19  2021-08  179.615462
# 20  2021-09  180.473355
# 21  2021-10  181.659670
# 22  2021-11  181.412124
# 23  2021-12  180.379652
# 24  2022-01  176.637887
# 25  2022-02  171.959629
# 26  2022-03  165.550000
# 27  2022-04  161.136644
# 28  2022-05  165.666043
# 29  2022-06  175.928230

# %% [markdown]
# # We define Customers Life Time Span function and calculate monthly Life Time Span

# %%
df1 = pd.read_csv('/Users/emreserhatakkas/Downloads/bq-results-20220718-133529-1658151349029.csv')

# %%
df1.head()
# Out:
#       user_id action period date_time
# 0  4496347601    NaN    NaN       NaN
# 1  4496347621    NaN    NaN       NaN
# 2  4496347631    NaN    NaN       NaN
# 3  4496347641    NaN    NaN       NaN
# 4  4496347651    NaN    NaN       NaN

# %%
df1 = df1.loc[(df1.date_time >= '2018-01')]

# %%
def period_calculater(row):
    if row['action'] == 'payment':
        multiplier = 1
    elif row['action'] == 'refund':
        multiplier = -1

    if row['period'] == '1 MONTH':
        return 1*multiplier
    elif row['period'] == '1 YEAR':
        return 12*multiplier
    elif row['period'] == '2 YEARS':
        return 24*multiplier
    else:
        return 0

# %%
df1['number_of_months'] = df1.apply(lambda row: period_calculater(row), axis = 1)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df1 = df1.sort_values(['user_id','date_time']).reset_index().drop(columns=['index'], axis = 1)
df1.head()
# Out:
#       user_id   action  period                date_time  number_of_months
# 0  4496352601  payment  1 YEAR  2020-01-07 20:15:13 UTC                12
# 1  4496352601  payment  1 YEAR  2021-01-14 21:17:22 UTC                12
# 2  4496352601   refund  1 YEAR  2021-01-15 04:11:04 UTC               -12
# 3  4496353001  payment  1 YEAR  2021-03-02 16:08:47 UTC                12
# 4  4496353001  payment  1 YEAR  2022-03-02 05:11:45 UTC                12

# %%
temp = df1.iloc[0]

for i, row in df1.iterrows():
    if row['period'] != '1 MONTH' and row['action'] == 'refund':
        if row['user_id'] == temp['user_id']:
            if pd.period_range(row['date_time'],freq='M',periods=1).strftime('%Y-%m').tolist()[0] != pd.period_range(temp['date_time'],freq='M',periods=1).strftime('%Y-%m').tolist()[0]:
                monthEnds = pd.period_range(row['date_time'],freq='M',periods=1) - pd.period_range(temp['date_time'],freq='M',periods=1)
                if row['period'] == '1 YEAR':
                    if str(monthEnds[0])[1] == 'M':
                        df1.at[i,'number_of_months'] = -11
                    else:
                        df1.at[i,'number_of_months'] = -1 * (12 - int(str(monthEnds[0]).split('<')[1].split(' * ')[0]))
                elif row['period'] == '2 YEARS':
                    if str(monthEnds[0])[1] == 'M':
                        df1.at[i,'number_of_months'] = -23
                    else:
                        df1.at[i,'number_of_months'] = -1 * (24 - int(str(monthEnds[0]).split('<')[1].split(' * ')[0]))
    temp = row

# %%
df1.loc[(df1.user_id == 4496487181)].sort_values('date_time', ascending=True)
# Out:
#         user_id   action  period                date_time  number_of_months
# 452  4496487181  payment  1 YEAR  2020-11-27 02:58:57 UTC                12
# 453  4496487181  payment  1 YEAR  2021-11-27 04:00:29 UTC                12
# 454  4496487181   refund  1 YEAR  2021-12-02 02:28:56 UTC               -11

# %%
dict_LifeTimeSpans = {}
for i, ym in enumerate(YearMonths[1:]):
    df1_temp = df1.loc[df1.date_time<ym]
    ever_paid_users = df1_temp.loc[(df1_temp.action == 'payment')].user_id.unique()
    df1_temp = df1_temp.loc[df1_temp.user_id.isin(ever_paid_users)]
    df1_temp.sort_values('user_id', ascending=True, inplace=True)
    df1_LifeTimeSpan = df1_temp.groupby('user_id').sum()['number_of_months']
    dict_LifeTimeSpans[YearMonths[i]] = df1_LifeTimeSpan.mean()

# %%
new_list_dates = list(dict_LifeTimeSpans.keys())
new_list_LifeTimeSpans = list(dict_LifeTimeSpans.values())

# %%
LifeTimeSpans = pd.DataFrame(list(zip(new_list_dates, new_list_LifeTimeSpans)),
                           columns =['Date', 'Life Time Span'])

# %%
LifeTimeSpans
# Out:
#        Date  Life Time Span
# 0   2020-01        6.030755
# 1   2020-02        6.096018
# 2   2020-03        6.095617
# 3   2020-04        5.924004
# 4   2020-05        6.071758
# 5   2020-06        6.129106
# 6   2020-07        6.240744
# 7   2020-08        6.649751
# 8   2020-09        6.683615
# 9   2020-10        6.701626
# 10  2020-11        6.972305
# 11  2020-12        7.326794
# 12  2021-01        7.572702
# 13  2021-02        7.637005
# 14  2021-03        7.704201
# 15  2021-04        7.825169
# 16  2021-05        8.034990
# 17  2021-06        8.239752
# 18  2021-07        8.412566
# 19  2021-08        8.776029
# 20  2021-09        8.845770
# 21  2021-10        8.914983
# 22  2021-11        9.183661
# 23  2021-12        9.572954
# 24  2022-01        9.813004
# 25  2022-02        9.926572
# 26  2022-03       10.038568
# 27  2022-04       10.234905
# 28  2022-05       10.503759
# 29  2022-06       10.845576

# %% [markdown]
# # Now we have a dataset with Life Time Spans and CLTVs. We begin to visualize this datasets

# %%
fig = px.bar(LifeTimeSpans, x="Date", y="Life Time Span", title="Churn Customers Average Life Time Spans (Month)",color_discrete_sequence=px.colors.qualitative.Dark2)
fig.show("png")

# %%
fig = px.line(LifeTimeSpans, x='Date', y="Life Time Span", title="Change of Churn Customers Average Life Time Span (Month)",  color_discrete_sequence=px.colors.qualitative.Light24)
fig.show("png")

# %%
fig = px.bar(CLTV, x="Date", y="CLTV", title="Monthly CLTV (USD)",color_discrete_sequence=px.colors.colorbrewer.RdGy)
fig.show("png")

# %%
fig = px.line(CLTV, x='Date', y="CLTV", title="Change of CLTV (USD)",  color_discrete_sequence=px.colors.qualitative.Vivid)
fig.show("png")

# %%
All_Data = pd.DataFrame(list(zip(stcr_date,stcr_values,mtcr_values,ltcr_values,totalchurn_values, cltv_list_values ,new_list_LifeTimeSpans)),
                           columns =['Date', 'Short-Term Churn Ratio', 'Mid-Term Churn Ratio','Long-Term Churn Ratio','Total Churn Ratio','CLTV','Life Time Span'])

# %%
All_Data
# Out:
#        Date  Short-Term Churn Ratio  Mid-Term Churn Ratio  \
# 0   2020-01                0.571429              0.000000
# 1   2020-02                0.521739              0.111111
# 2   2020-03                0.350000              0.047619
# 3   2020-04                0.307692              0.131579
# 4   2020-05                0.339744              0.210526
# 5   2020-06                0.359833              0.258824
# 6   2020-07                0.343333              0.322034
# 7   2020-08                0.345455              0.436709
# 8   2020-09                0.361702              0.500000
# 9   2020-10                0.374552              0.534137
# 10  2020-11                0.399707              0.589744
# 11  2020-12                0.409034              0.610080
# 12  2021-01                0.419142              0.665227
# 13  2021-02                0.475970              0.698885
# 14  2021-03                0.531883              0.688088
# 15  2021-04                0.555415              0.695138
# 16  2021-05                0.565265              0.689989
# 17  2021-06                0.578529              0.697479
# 18  2021-07                0.582569              0.705882
# 19  2021-08                0.586162              0.712000
# 20  2021-09                0.593900              0.714754
# 21  2021-10                0.606809              0.721223
# 22  2021-11                0.620537              0.721539
# 23  2021-12                0.647399              0.733589
# 24  2022-01                0.672163              0.755487
# 25  2022-02                0.696658              0.767327
# 26  2022-03                0.727815              0.783537
# 27  2022-04                0.758821              0.808014
# 28  2022-05                0.774597              0.850597
# 29  2022-06                0.792089              0.902269
#
#     Long-Term Churn Ratio  Total Churn Ratio        CLTV  Life Time Span
# 0                     NaN           0.205882  169.222345        6.030755
# 1                0.000000           0.165517  169.511607        6.096018
# 2                0.000000           0.154856  169.894711        6.095617
# 3                0.026316           0.158358  170.170980        5.924004
# 4                0.017857           0.148214  171.077384        6.071758
# 5                0.011628           0.149767  171.846360        6.129106
# 6                0.034483           0.144017  172.677354        6.240744
# 7                0.024845           0.149077  173.371242        6.649751
# 8                0.020408           0.150703  174.271931        6.683615
# 9                0.021645           0.150634  175.012974        6.701626
# 10               0.025180           0.157914  176.151941        6.972305
# 11               0.034268           0.160200  176.824630        7.326794
# 12               0.035422           0.167335  176.703996        7.572702
# 13               0.040000           0.180452  176.888094        7.637005
# 14               0.052009           0.195429  177.624962        7.704201
# 15               0.054945           0.205781  178.266299        7.825169
# 16               0.069815           0.213766  178.874901        8.034990
# 17               0.086538           0.217821  179.861116        8.239752
# 18               0.093923           0.220232  180.258527        8.412566
# 19               0.118467           0.220133  179.615462        8.776029
# 20               0.140940           0.222161  180.473355        8.845770
# 21               0.175439           0.224123  181.659670        8.914983
# 22               0.240117           0.232369  181.412124        9.183661
# 23               0.288828           0.244758  180.379652        9.572954
# 24               0.340076           0.254723  176.637887        9.813004
# 25               0.379808           0.263504  171.959629        9.926572
# 26               0.433036           0.279068  165.550000       10.038568
# 27               0.487020           0.299414  161.136644       10.234905
# 28               0.556731           0.313149  165.666043       10.503759
# 29               0.623540           0.320329  175.928230       10.845576

# %% [markdown]
# # Let's move on to EDA (Exploratory Data Analysis)

# %% [markdown]
# In statistics, exploratory data analysis is an approach of analyzing data sets to summarize their main characteristics, often using statistical graphics and other data visualization methods.

# %%
all_churnrates.describe().T
# Out:
#                         count      mean       std       min       25%  \
# Short-Term Churn Ratio   30.0  0.528998  0.147047  0.307692  0.380841
# Mid-Term Churn Ratio     30.0  0.568780  0.255751  0.000000  0.452532
# Long-Term Churn Ratio    30.0  0.147776  0.182832  0.000000  0.024929
# Total Churn Ratio        30.0  0.205656  0.052714  0.144017  0.158025
#
#                              50%       75%       max
# Short-Term Churn Ratio  0.560340  0.617105  0.792089
# Mid-Term Churn Ratio    0.692564  0.721460  0.902269
# Long-Term Churn Ratio   0.053477  0.223947  0.623540
# Total Churn Ratio       0.205832  0.230308  0.320329

# %%
CLTV.describe().T
# Out:
#       count        mean       std         min         25%         50%  \
# CLTV   30.0  174.631002  5.202013  161.136644  171.269628  176.040085
#
#             75%        max
# CLTV  178.72275  181.65967

# %%
LifeTimeSpans.describe().T
# Out:
#                 count      mean       std       min       25%       50%  \
# Life Time Span   30.0  7.966809  1.550057  5.924004  6.658217  7.764685
#
#                      75%        max
# Life Time Span  9.116491  10.845576

# %% [markdown]
# # Outlier Analysis with Boxplot

# %%
y0 = all_churnrates['Short-Term Churn Ratio']
y1 = all_churnrates['Mid-Term Churn Ratio']
y2 = all_churnrates['Long-Term Churn Ratio']
y3 = all_churnrates['Total Churn Ratio']
fig3 = px.box(CLTV, y="CLTV", points = "all", title = "Boxplot of Churn Customers CLTVs")
fig4 = px.box(LifeTimeSpans, y="Life Time Span", points = "all", title = "Boxplot of Churn Customers Average Life Time Spans")
fig = go.Figure()
fig.add_trace(go.Box(y=y0, name="Short-Term Churn Ratio", boxpoints = 'all'))
fig.add_trace(go.Box(y=y1, name="Mid-Term Churn Ratio", boxpoints = 'all'))
fig.add_trace(go.Box(y=y2, name="Long-Term Churn Ratio", boxpoints = 'all'))
fig.add_trace(go.Box(y=y3, name="Total Churn Ratio", boxpoints = 'all'))
fig.update_layout(title_text="All Churn Rates Boxplots")
fig.show("png")
fig3.show("png")
fig4.show("png")

# %% [markdown]
# We have an outlier at Long-Term Churn Ratio value in Churn Ratios. But this is not an outlier that could pose a problem for the remainder of our analysis because this outlier is not a calculation error.

# %% [markdown]
# # Distribution Analysis

# %% [markdown]
# It is very important for us to know the distribution of our data in order to further refine our analysis.

# %%
x01 = all_churnrates['Short-Term Churn Ratio']
x02 = all_churnrates['Mid-Term Churn Ratio']
x03 = all_churnrates['Long-Term Churn Ratio']
x04 = all_churnrates['Total Churn Ratio']

hist_data = [x01, x02, x03, x04]

group_labels = ['Short-Term Churn Ratio', 'Mid-Term Churn Ratio', 'Long-Term Churn Ratio', 'Total Churn Ratio']
fig = ff.create_distplot(hist_data, group_labels, bin_size=.09)
fig.update_layout(title_text="All Churn Rates Distribution Plot")
fig.show("png")

x05 = CLTV.CLTV
x06 = LifeTimeSpans['Life Time Span']

hist_data1 = [x05]
hist_data2 = [x06]
group_labels1 = ['CLTV']
group_labels2 = ['Life Time Span']
fig1 = ff.create_distplot(hist_data1, group_labels1)
fig2 = ff.create_distplot(hist_data2, group_labels2)
fig1.update_layout(title_text="CLTVs Distribution Plot")
fig2.update_layout(title_text="Customers Average Life Time Spans Distribution Plot")
fig1.show("png")
fig2.show("png")

# %% [markdown]
# # Correlation Analysis

# %% [markdown]
# In the Correlation Matrix, each box takes a value between -1 and +1. If this value is close to -1, we say that there is a strong negative relationship between these two variables, and if it is close to +1, we say that there is a strong positive relationship between them. If it is close to zero, we can say that there is no relationship between these two variables. The range that we will assume there is no relationship is -0.2 < cc < 0.2. (cc: correlation coefficent)

# %% [markdown]
# None of our data has a normal distribution. So we can use Spearmann's correlation coefficient to measure the meaning of the relationship between them. It should be noted that Pearon's correlation coefficient is valid only for data with normal distribution.

# %%
corr = All_Data.corr(method = 'spearman')
corr
# Out:
#                         Short-Term Churn Ratio  Mid-Term Churn Ratio  \
# Short-Term Churn Ratio                1.000000              0.894549
# Mid-Term Churn Ratio                  0.894549              1.000000
# Long-Term Churn Ratio                 0.924744              0.972780
# Total Churn Ratio                     0.978198              0.890100
# CLTV                                  0.165295              0.280534
# Life Time Span                        0.922136              0.990211
#
#                         Long-Term Churn Ratio  Total Churn Ratio      CLTV  \
# Short-Term Churn Ratio               0.924744           0.978198  0.165295
# Mid-Term Churn Ratio                 0.972780           0.890100  0.280534
# Long-Term Churn Ratio                1.000000           0.939525  0.223427
# Total Churn Ratio                    0.939525           1.000000  0.162625
# CLTV                                 0.223427           0.162625  1.000000
# Life Time Span                       0.968346           0.905673  0.280979
#
#                         Life Time Span
# Short-Term Churn Ratio        0.922136
# Mid-Term Churn Ratio          0.990211
# Long-Term Churn Ratio         0.968346
# Total Churn Ratio             0.905673
# CLTV                          0.280979
# Life Time Span                1.000000

# %%
fig = px.imshow(corr, text_auto=True, aspect="auto", title="Correlation matrix between variables")
fig.show("png")

# %% [markdown]
# # Simple Linear Regression Modelling and test of the Model's Significance

# %% [markdown]
# Correlation can only tell us whether there is a relationship between these two variables and its strength. But is it regression? Of course not, the regression can tell us the effect of Total Churn Ratio on Life Time Spans. However, regression can only estimate and give us an approximation.

# %%
fig = px.scatter(x=All_Data['Total Churn Ratio'], y=All_Data['Life Time Span'], title="Scatter Plot between Total Churn Ratio(x) and Life Time Span(y)")
fig.show("png")

# %%
x001 = All_Data['Total Churn Ratio']
y001 = All_Data['Life Time Span']
x001 = sm.add_constant(x001)
model = sm.OLS(y001,x001).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Life Time Span   R-squared:                       0.880
# Model:                            OLS   Adj. R-squared:                  0.875
# Method:                 Least Squares   F-statistic:                     204.8
# Date:                Mon, 01 Aug 2022   Prob (F-statistic):           2.10e-14
# Time:                        04:24:49   Log-Likelihood:                -23.438
# No. Observations:                  30   AIC:                             50.88
# Df Residuals:                      28   BIC:                             53.68
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 2.2948      0.409      5.614      0.000       1.458       3.132
# Total Churn Ratio    27.5801      1.927     14.311      0.000      23.632      31.528
# ==============================================================================
# Omnibus:                       20.438   Durbin-Watson:                   0.316
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.149
# Skew:                          -1.619   Prob(JB):                     2.84e-07
# Kurtosis:                       6.692   Cond. No.                         20.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## There are 2 important points for us in this table, and when we interpret the values at these 2 points, our analysis will be fully understood.

# %% [markdown]
# Coefficients : The regression coefficient is a statistical measure of the average functional relationship between two or more variables. In Table 2, where it is written for const, it gives the value of the constant in the regression formula, and where it is written for Total Churn Ratio, it shows how much the Life Time Span will change with one unit change in Total Churn Ratio. Therefore, the regression model makes use of the coefficients here when making predictions.

# %% [markdown]
# P-Value: This value gives us whether the coefficient obtained from the independent variable is statistically significant. The significance value generally accepted in the scientific world is p < 0.05. If the result is above this value, the effect of the relevant independent variable on the model is not significant. This value is used during the selection of variables in multivariate regression analysis. In our table, this value is < 0.05 and therefore the regression model we created is also significant.

# %% [markdown]
# ## Now that we have examined our table, let's draw the regression line formed as a result of the model on the scatter plot above.

# %%
fig = px.scatter(
    All_Data, x='Total Churn Ratio', y='Life Time Span', opacity=0.65,
    trendline='ols', trendline_color_override='red')
fig.show("png")

# %% [markdown]
# As can be seen in this graph, the regression line is drawn with the least error between the points.
